# %% [markdown]
# # 2NA Assignment 4
#
# Connor Goosen<br>
# GSNCON001

# %% [markdown]
# ## Analytical Problems
#
# Let:
#  - $y_1 = y$
#  - $y_2 = y'$
#  - $y_3 = y''$
#
# Therefore<br>
# $y_2' = y_3$<br>
# $y_1' = y_2$<br>
# $y_3' = \cos(y_1)+\sin(y_2) + e^{y_3} + t^3$
#
# Where $y_1(0) = 3$, $y_2(0) = 7$, and $y_3(0) = 13$

# %% [markdown]
# ## Numerical Problems

# %%
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format ='retina' #Increases resolution of plots

# %% [markdown]
# Using Euler's method to solve the Differential Equaiton can be shown in the code below:

# %%
n=101
t=np.linspace(0,5, n)
na = [100]
nb = [0]

for i in range(1,n): #The loop starts at 1 to avoid an index out of bounds error.
    na.append( 0.05*(-1*na[i-1]) + na[i-1] )
    nb.append( 0.05*(na[i-1]-nb[i-1]) +z[i-1] )

plt.figure(figsize = (20, 10))
plt.plot(t,na, '--', label=r'$N_A$')
plt.plot(t,nb, '-', label=r'$N_B$')
plt.xlabel('Time (s)')
plt.ylabel(r'$N_A(t)$, and $N_B(t)$')
plt.title('The transition from type A nuclei to type B nuclei over time')
plt.legend( loc='upper right', numpoints = 2 )

# %% [markdown]
# This shows the neuclei transitioning from type A to type B while the B type nuclei themselves are decaying<br>
# The actual esimates over the time range can be shown in the table below
#
# | Time | $N_A(t)$ | $N_B(t)$ |
# | --- | --- | --- |
# | 0.0 | 100.0 | 0.0 |
# | 0.05 | 95.0 | 5.0 |
# | 0.1 | 90.25 | 9.5 |
# | 0.15000000000000002 | 85.7375 | 13.537500000000001 |
# | 0.2 | 81.450625 | 17.1475 |
# | 0.25 | 77.37809375 | 20.36265625 |
# | 0.30000000000000004 | 73.5091890625 | 23.213428125 |
# | 0.35000000000000003 | 69.833729609375 | 25.728216171875 |
# | 0.4 | 66.34204312890625 | 27.93349184375 |
# | 0.45 | 63.02494097246094 | 29.853919408007815 |
# | 0.5 | 59.87369392383789 | 31.512470486230473 |
# | 0.55 | 56.880009227646 | 32.930531658110844 |
# | 0.6000000000000001 | 54.0360087662637 | 34.1280055365876 |
# | 0.65 | 51.33420832795051 | 35.12340569807141 |
# | 0.7000000000000001 | 48.76749791155299 | 35.93394582956537 |
# | 0.75 | 46.329123015975334 | 36.575623433664745 |
# | 0.8 | 44.01266686517657 | 37.06329841278028 |
# | 0.8500000000000001 | 41.81203352191774 | 37.41076683540009 |
# | 0.9 | 39.721431845821854 | 37.630830169725975 |
# | 0.9500000000000001 | 37.735360253530764 | 37.73536025353077 |
# | 1.0 | 35.848592240854224 | 37.73536025353077 |
# | 1.05 | 34.056162628811514 | 37.64102185289694 |
# | 1.1 | 32.35335449737094 | 37.46177889169267 |
# | 1.1500000000000001 | 30.73568677250239 | 37.20635767197658 |
# | 1.2000000000000002 | 29.198902433877272 | 36.88282412700288 |
# | 1.25 | 27.73895731218341 | 36.498628042346596 |
# | 1.3 | 26.35200944657424 | 36.06064450583844 |
# | 1.35 | 25.034408974245526 | 35.57521275287523 |
# | 1.4000000000000001 | 23.78268852553325 | 35.048172563943744 |
# | 1.4500000000000002 | 22.593554099256586 | 34.484898362023216 |
# | 1.5 | 21.463876394293756 | 33.89033114888488 |
# | 1.55 | 20.390682574579067 | 33.269008411155326 |
# | 1.6 | 19.371148445850114 | 32.62509211932651 |
# | 1.6500000000000001 | 18.40259102355761 | 31.96239493565269 |
# | 1.7000000000000002 | 17.48246147237973 | 31.284404740047936 |
# | 1.75 | 16.608338398760743 | 30.594307576664526 |
# | 1.8 | 15.777921478822707 | 29.895009117769337 |
# | 1.85 | 14.989025404881572 | 29.189154735822004 |
# | 1.9000000000000001 | 14.239574134637493 | 28.479148269274983 |
# | 1.9500000000000002 | 13.527595427905618 | 27.76716956254311 |
